# %% [markdown]
# # Descarga imagen
#
# En primer lugar vamos a descargar la imagen con la que vamos a trabajar en la primera parte de la sesión.

# %%
# # Importamos librerías para interactuar con Google Drive
# from pydrive.auth import GoogleAuth
# from pydrive.drive import GoogleDrive
# from google.colab import auth
# from oauth2client.client import GoogleCredentials
# 
# # Nos autenticamos con nuestra cuenta de Google Drive para acceder a los datos
# auth.authenticate_user()
# gauth = GoogleAuth()
# gauth.credentials = GoogleCredentials.get_application_default()
# drive = GoogleDrive(gauth)
# 
# # Nos descargamos las imagenes que vamos a emplear
# download = drive.CreateFile({'id': '1sUgi4yM7If5YuynuswaN1UIajmpQq0-w'})
# download.GetContentFile('imagen2.jpeg')

# %% [markdown]
# # Parte I: Filtro convolucional
#
# Vamos a visualizar los filtros ajustados por una CNN ya existente, así como el mapa de características (imagen filtrada) generada por dichos filtros.
#
# Para ello, vamos a emplear una arquitectura que se diseñó hace unos años (VGG16 - 2014) y que fue entrenada sobre la base de datos de ImageNet.
#
# Por lo tanto, lo primero que vamos a hacer es importar dicha arquitectura que se encuentra dentro de la propia API de Tensorflow.

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.models import Model

# %%
model = VGG16(include_top=False, weights='imagenet')

model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\JulianBSL\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# WARNING:tensorflow:From C:\Users\JulianBSL\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 6s 0us/step
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]   0
#
#  block1_conv1 (Conv2D)       (None, None, None, 64)    1792
#
#  block1_conv2 (Conv2D)       (None, None, None, 64)    36928
#
#  block1_pool (MaxPooling2D)  (None, None, None, 64)    0
#
#  block2_conv1 (Conv2D)       (None, None, None, 128)   73856
#
#  block2_conv2 (Conv2D)       (None, None, None, 128)   147584
#
#  block2_pool (MaxPooling2D)  (None, None, None, 128)   0
#
#  block3_conv1 (Conv2D)       (None, None, None, 256)   295168
#
#  block3_conv2 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv3 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_pool (MaxPooling2D)  (None, None, None, 256)   0
#
#  block4_conv1 (Conv2D)       (None, None, None, 512)   1180160
#
#  block4_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_pool (MaxPooling2D)  (None, None, None, 512)   0
#
#  block5_conv1 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_pool (MaxPooling2D)  (None, None, None, 512)   0
#
# =================================================================
# Total params: 14714688 (56.13 MB)
# Trainable params: 14714688 (56.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Mostramos las capas convolucionales que contiene VGG16

for l, layer in enumerate(model.layers):
    if 'conv' in layer.name:
        filters, biases = layer.get_weights()
        print('Capa', l, ':', layer.name, filters.shape)
# Out:
# Capa 1 : block1_conv1 (3, 3, 3, 64)
# Capa 2 : block1_conv2 (3, 3, 64, 64)
# Capa 4 : block2_conv1 (3, 3, 64, 128)
# Capa 5 : block2_conv2 (3, 3, 128, 128)
# Capa 7 : block3_conv1 (3, 3, 128, 256)
# Capa 8 : block3_conv2 (3, 3, 256, 256)
# Capa 9 : block3_conv3 (3, 3, 256, 256)
# Capa 11 : block4_conv1 (3, 3, 256, 512)
# Capa 12 : block4_conv2 (3, 3, 512, 512)
# Capa 13 : block4_conv3 (3, 3, 512, 512)
# Capa 15 : block5_conv1 (3, 3, 512, 512)
# Capa 16 : block5_conv2 (3, 3, 512, 512)
# Capa 17 : block5_conv3 (3, 3, 512, 512)

# %%
# Cogemos los pesos aprendidos (filtros y sesgo) de la primera capa
filters, biases = model.layers[1].get_weights()

print('Número filtros: ', filters.shape[3])
print('Número canales: ', filters.shape[2])
print('Tamaño de cada filtro: ', filters.shape[:2])
# Out:
# Número filtros:  64
# Número canales:  3
# Tamaño de cada filtro:  (3, 3)

# %%
# Normalizamos los valores de los filtros para que estén contenidos entre 0 y 1 y se puedan visualizar adecuadamente
f_min, f_max = filters.min(), filters.max()
filters = (filters - f_min) / (f_max - f_min)

# Vamos a visualizar 10 filtros
n_filters, ix = 10, 1

plt.figure(figsize=(10, 20))

for i in range(n_filters):

    f = filters[:, :, :, i]

    # Para cada filtro visualizamos 3 canales
    for j in range(3):
        ax = plt.subplot(n_filters, 3, ix)
        ax.set_xticks([])
        ax.set_yticks([])

        plt.imshow(f[:, :, j], cmap='gray')
        ix += 1

plt.show()

# %% [markdown]
# En la figura anterior podemos ver los filtros obtenidos en la primera capa convolucional de la arquitectura que hemos cargado (VGG16). En esta capa tenemos, para cada canal de la capa anterior (3 canales en nuestro caso), 64 filtros de 3x3.
# En filas hemos representado 20 de los 64 filtros y en cada columna tenemos el filtro para cada uno de los 3 canales.
# Podemos ver que hay algunos casos en los que los filtros son iguales para los tres canales (e.g. primera fila), mientras que en otros casos, los filtros son diferentes.
#
# Los cuadrados más negros indican un valor de peso bajo, mientras que cuadrados más claros indican un valor de peso alto. Por lo tanto, podríamos decir que en la primera fila tenemos filtros que detectan gradientes de intensidad de claro en la esquina superior izquierda a oscuro en la esquina inferior derecha. O, por ejemplo, en la quinta y septima fila vemos filtros que destacan esquinas.

# %% [markdown]
# A continuación, vamos a ver las imágenes que salen de un filtro convolucional (mapa de características).

# %%
# Cargamos imagen y la preprocesamos
image = Image.open('imagen2.jpeg')
image = np.array(image)
plt.imshow(image)
plt.axis('off')
# Out:
# (-0.5, 1499.5, 999.5, -0.5)

# %%
# Preparamos la imagen para introducirla en el modelo para que tenga el formato [n casos, n filas, n columnas, n canales]
image = np.expand_dims(image, axis=0)

# Función para preprocesar la imagen de igual forma que se hizo para el desarrollo de VGG16
image = preprocess_input(image)

print('Tamaño imagen: ', image.shape)
# Out:
# Tamaño imagen:  (1, 1000, 1500, 3)

# %%
# Seleccionamos capa de la que queremos generar el mapa de características
layer = model.layers[2]
# Creamos modelo auxiliar en el que a la salida tengamos la salida de la capa deseada
model_aux = Model(inputs=[model.input], outputs=[layer.output])

# Generamos mapa de características
feature_maps = model_aux.predict(image)
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
feature_maps.shape
# Out:
# (1, 1000, 1500, 64)

# %%
square = 8
ix = 1
plt.figure(figsize=(20, 12))
for _ in range(square):
    for _ in range(square):
        ax = plt.subplot(square, square, ix)
        ax.set_xticks([])
        ax.set_yticks([])
        plt.imshow(feature_maps[0, :, :, ix - 1], cmap='gray')
        ix += 1
plt.show()

# %% [markdown]
# # Parte II: Bloques redes neuronales convolucionales
#
# En esta segunda parte de la sesión vamos a ver cómo implementar algunos de los bloques principales que podemos encontrar en una CNN haciendo uso de la API de Tensorflow/Keras.

# %% [markdown]
# Vamos a cargar una imagen que será la que emplearemos para ver la salida de cada uno de los bloques que implementemos.

# %%
from tensorflow.keras import layers

# %%
img = Image.open('imagen2.jpeg')
img = np.array(img)

# Añadimos primera dimensión para construir matriz tal que tengamos [n imagenes, n filas, n columnas, n canales]
img = np.expand_dims(img, axis=0)

print('Tamaño de imagen original: ', img.shape)
# Out:
# Tamaño de imagen original:  (1, 1000, 1500, 3)

# %% [markdown]
# ## Filtro convolucional

# %%
# Capa de entrada donde especificamos el tamaño de la imagen de entrada (n filas, n columnas, n canales)
input_layer = layers.Input(shape=img.shape[1:])

# Capa convolucional con 8 filtros de tamaño 3x3
layer_conv = layers.Conv2D(filters=8, kernel_size=(3, 3))(input_layer)

model = Model(inputs=[input_layer], outputs=[layer_conv])

model.summary()
# Out:
# Model: "model_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_24 (InputLayer)       [(None, 1000, 1500, 3)]   0
#
#  conv2d_56 (Conv2D)          (None, 998, 1498, 8)      224
#
# =================================================================
# Total params: 224
# Trainable params: 224
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# En la anterior capa convolucional no hemos especificado ni el stride ni el padding. Si miramos la [documentación de Keras](https://keras.io/api/layers/convolution_layers/convolution2d/), si no se especifica nada, por defecto se toma un valor de strides=(1,1) y padding="valid". Si queremos cambiar su valor deberemos de especificarlo.

# %%
# Vemos el efecto del stride

input_layer = layers.Input(shape=img.shape[1:])

layer_conv = layers.Conv2D(filters=8, kernel_size=(3, 3), strides=(2, 2))(input_layer)

model = Model(inputs=[input_layer], outputs=[layer_conv])

model.summary()
# Out:
# Model: "model_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_17 (InputLayer)       [(None, 1000, 1500, 3)]   0
#
#  conv2d_48 (Conv2D)          (None, 499, 749, 8)       224
#
# =================================================================
# Total params: 224
# Trainable params: 224
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Vemos el efecto del padding

input_layer = layers.Input(shape=img.shape[1:])

layer_conv = layers.Conv2D(filters=8, kernel_size=(3, 3), strides=(2, 2), padding="same")(input_layer)

model = Model(inputs=[input_layer], outputs=[layer_conv])

model.summary()
# Out:
# Model: "model_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_18 (InputLayer)       [(None, 1000, 1500, 3)]   0
#
#  conv2d_49 (Conv2D)          (None, 500, 750, 8)       224
#
# =================================================================
# Total params: 224
# Trainable params: 224
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **¿Por qué se ha reducido la imagen a la mitad si hemos puesto padding="same"?**

# %% [markdown]
# Vemos el tamaño de la imagen de salida que genera la última capa que hemos creado y si se corresponde con lo que dice el "summary".

# %%
img_model = model.predict(img)

print('Tamaño imagen filtrada: ', layer_conv.shape)
# Out:
# Tamaño imagen filtrada:  (None, 500, 750, 8)

# %% [markdown]
# **¿Por qué la imagen de salida tiene 8 canales?**

# %% [markdown]
# ## Ejercicio 1
#
# Implementa una capa convolucional con las siguientes propiedades:
#
# * Tamaño de filtro: 5x5
# * Número de filtros: 16
# * Stride: 1x1
# * Padding: Aquel que genere una imagen de salida de igual tamaño que la imagen de entrada.
#
# Preguntas:
# * Calcula el número de parámetros que va a tener que ajustar la capa que hemos implementado, ¿coincide con lo especificado por Keras?
# * ¿Cuál es el tamaño de la imagen de salida?
# * ¿Qué padding es el apropiada para conseguir nuestros objetivos?

# %%
exercise1_input_layer = layers.Input(shape=img.shape[1:])

exercise1_layer_conv = layers.Conv2D(filters=16, kernel_size=(5, 5), strides=(1, 1), padding="same")(
    exercise1_input_layer)

exercise1_model = Model(inputs=[exercise1_input_layer], outputs=[exercise1_layer_conv])

exercise1_model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 1000, 1500, 3)]   0
#
#  conv2d_1 (Conv2D)           (None, 1000, 1500, 16)    1216
#
# =================================================================
# Total params: 1216 (4.75 KB)
# Trainable params: 1216 (4.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# - El numero de parametros es (5 * 5 * 3 + 1) * 16 = 1216 parametros. Si coincide con lo especificado por keras
# - La imagen de salida tendra las mismas dimensiones que la imagen de entrada
# - El padding apropiado es 'same'

# %% [markdown]
# ## Función de activación
#
# Tras cada filtro convolucional hay que aplicar una función de activación.
# Esta se puede implementar de dos formas diferentes:
#
# * Como argumento dentro de la capa convolucional.
# * Como un capa nueva tras la capa convolucional.

# %%
# Como argumento dentro de la capa convolucional
input_layer = layers.Input(shape=img.shape[1:])
layer_conv = layers.Conv2D(filters=8, kernel_size=(3, 3), strides=(2, 2), padding="same", activation="relu")(
    input_layer)

model = Model(inputs=[input_layer], outputs=[layer_conv])

model.summary()
# Out:
# Model: "model_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_19 (InputLayer)       [(None, 1000, 1500, 3)]   0
#
#  conv2d_50 (Conv2D)          (None, 500, 750, 8)       224
#
# =================================================================
# Total params: 224
# Trainable params: 224
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Como una capa nueva tras la capa convolucional
input_layer = layers.Input(shape=img.shape[1:])
layer_conv = layers.Conv2D(filters=8, kernel_size=(3, 3), strides=(2, 2), padding="same")(input_layer)
act = layers.Activation("relu")(layer_conv)

model = Model(inputs=[input_layer], outputs=[act])

model.summary()
# Out:
# Model: "model_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_20 (InputLayer)       [(None, 1000, 1500, 3)]   0
#
#  conv2d_51 (Conv2D)          (None, 500, 750, 8)       224
#
#  activation (Activation)     (None, 500, 750, 8)       0
#
# =================================================================
# Total params: 224
# Trainable params: 224
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Esta segunda opción es de especial interés cuando queremos emplear una función de activación parametrizable (e.g., LeakyRelu).

# %% [markdown]
# **NOTA:** Cuando la función de activación se intrudza como argumento dentro de la capa convolucional no la veremos reflejada en el "summary", en cambio, cuando la incorporemos como capa adicional si aparecerá. Ambas aproximaciones dan el mismo resultado.

# %% [markdown]
# **NOTA:** No vamos a experimentar más con las funciones de activación ya que lo veréis en la parte de datos estructurados, donde se emplean las mismas funciones de activación que en CNNs.
#
# Únicamente nos vamos a quedar con que para filtros convolucionales en la gran mayoría de los casos vamos a emplear función de activación ReLU (para casos particulares lo iremos viendo conforme nos los vayamos encontrando).

# %% [markdown]
# ## Pooling o agrupación
#
# En Keras emplearemos la clase MaxPool2D o MaxPooling2D (ambas hacen lo mismo).

# %%
input_layer = layers.Input(shape=img.shape[1:])
layer_conv = layers.Conv2D(filters=8, kernel_size=(3, 3), strides=(2, 2), padding="same", activation="relu")(
    input_layer)
# Capa de Max pooling para dividir la imagen a la mitad
pool = layers.MaxPool2D(pool_size=(2, 2))(layer_conv)

model = Model(inputs=[input_layer], outputs=[pool])

model.summary()
# Out:
# Model: "model_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_22 (InputLayer)       [(None, 1000, 1500, 3)]   0
#
#  conv2d_53 (Conv2D)          (None, 500, 750, 8)       224
#
#  max_pooling2d_19 (MaxPoolin  (None, 250, 375, 8)      0
#  g2D)
#
# =================================================================
# Total params: 224
# Trainable params: 224
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Ejercicio 2
#
# Implementa un modelo que tenga las siguientes características:
#
# * Capa de entrada de tamaño 256x256x3
# * Dos capas convolucionales (una a continuación de la otra) con las siguientes propiedades:
#       * 1ª capa: 16 filtros de 3x3, con stride (1,1) y padding tal que mantenga el tamaño de la imagen de entrada.
#       * 2ª capa: 32 filtros de 5x5, con stride (2,2) y sin padding.
#
# * Las dos capas convolucionales emplearán una función de activación ReLU.
# * Capa de Max Pooling de forma que se reduzca el tamaño de la imagen a la mitad.
#
# **PREGUNTAS:**
# * ¿Qué tamaño de imagen de salida habéis obtenido?
# * ¿Cuántos parámetros debe ajustar el modelo en total?

# %%
exercise2_input_layer = layers.Input(shape=(256, 256, 3))

exercise2_layer_conv_1 = layers.Conv2D(filters=16, kernel_size=(3, 3), strides=(1, 1), padding="same",
                                       activation="relu")(exercise2_input_layer)
exercise2_layer_conv_2 = layers.Conv2D(filters=32, kernel_size=(5, 5), strides=(2, 2), padding="valid",
                                       activation="relu")(exercise2_layer_conv_1)

exercise2_pool = layers.MaxPool2D(pool_size=(2, 2))(exercise2_layer_conv_2)

exercise2_model = Model(inputs=[exercise2_input_layer], outputs=[exercise2_pool])

exercise2_model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  conv2d_2 (Conv2D)           (None, 256, 256, 16)      448
#
#  conv2d_3 (Conv2D)           (None, 126, 126, 32)      12832
#
#  max_pooling2d (MaxPooling2  (None, 63, 63, 32)        0
#  D)
#
# =================================================================
# Total params: 13280 (51.88 KB)
# Trainable params: 13280 (51.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# - La imagen de salida es de 63 x 63 (x 32 canales)
# - La red debe ajustar un total de 13.280 parametros

# %% [markdown]
# ## Clasificación
#
# Ahora vamos a ver como tenemos que diseñar la CNN para resolver una problema de clasificación y que bloques vamos a emplear.

# %% [markdown]
# ### Flatten / Global Average Pooling
#
# Ambas capas se emplean para convertir la salida de la última capa de extracción de características donde tenemos imágenes (matrices) en un vector.

# %%
input_layer = layers.Input(shape=img.shape[1:])
layer_conv = layers.Conv2D(filters=8, kernel_size=(3, 3), strides=(2, 2), padding="same", activation="relu")(
    input_layer)
pool = layers.MaxPool2D(pool_size=(2, 2))(layer_conv)

# Capa de flatten
flatten = layers.Flatten()(pool)

model = Model(inputs=[input_layer], outputs=[flatten])

model.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 1000, 1500, 3)]   0
#
#  conv2d_4 (Conv2D)           (None, 500, 750, 8)       224
#
#  max_pooling2d_1 (MaxPoolin  (None, 250, 375, 8)       0
#  g2D)
#
#  flatten (Flatten)           (None, 750000)            0
#
# =================================================================
# Total params: 224 (896.00 Byte)
# Trainable params: 224 (896.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# La capa Flatten convierte la salida de la capa anterior en un vector sin aplicarles ningún tipo de transformación. Por ese motivo, la capa flatten genera como salida un vector de tamaño 750000 (250*375*8).

# %%
input_layer = layers.Input(shape=img.shape[1:])
layer_conv = layers.Conv2D(filters=8, kernel_size=(3, 3), strides=(2, 2), padding="same", activation="relu")(
    input_layer)
pool = layers.MaxPool2D(pool_size=(2, 2))(layer_conv)

# Capa de GlobalAveragePooling
global_avg = layers.GlobalAveragePooling2D()(pool)

model = Model(inputs=[input_layer], outputs=[global_avg])

model.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 1000, 1500, 3)]   0
#
#  conv2d_5 (Conv2D)           (None, 500, 750, 8)       224
#
#  max_pooling2d_2 (MaxPoolin  (None, 250, 375, 8)       0
#  g2D)
#
#  global_average_pooling2d (  (None, 8)                 0
#  GlobalAveragePooling2D)
#
# =================================================================
# Total params: 224 (896.00 Byte)
# Trainable params: 224 (896.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# La capa Global Average Pooling genera un vector de tantas componentes como canales tiene la imagen de salida de la capa anterior y, por cada canal, preserva el valor medio.
# Por ello, como la capa anterior (max_pooling_2d) tiene 8 canales, la salida de la capa de global_average_pooling tiene es un vector de 8 componentes.

# %% [markdown]
# ### Capa totalmente conectada (Dense)
#
# Finalmente vamos a implementar una serie de capas ocultas y la capa de salida para resolver un problema de calsificación.

# %%
input_layer = layers.Input(shape=img.shape[1:])
layer_conv = layers.Conv2D(filters=8, kernel_size=(3, 3), strides=(2, 2), padding="same", activation="relu")(
    input_layer)
pool = layers.MaxPool2D(pool_size=(2, 2))(layer_conv)

global_avg = layers.GlobalAveragePooling2D()(pool)

# Capa oculta
dense_hidden = layers.Dense(32, activation='relu')(global_avg)
# Capa de salida: suponemos problema de clasificación multiclase con 4 salidas
dense_output = layers.Dense(4, activation='softmax')(dense_hidden)

model = Model(inputs=[input_layer], outputs=[dense_output])

model.summary()
# Out:
# Model: "model_30"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_32 (InputLayer)       [(None, 1000, 1500, 3)]   0
#
#  conv2d_66 (Conv2D)          (None, 500, 750, 8)       224
#
#  max_pooling2d_31 (MaxPoolin  (None, 250, 375, 8)      0
#  g2D)
#
#  global_average_pooling2d_3   (None, 8)                0
#  (GlobalAveragePooling2D)
#
#  dense_26 (Dense)            (None, 32)                288
#
#  dense_27 (Dense)            (None, 4)                 132
#
# =================================================================
# Total params: 644
# Trainable params: 644
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Ejercicio 3
#
# Implementa la misma arquitectura que en el Ejercicio 2 y añade las siguientes capas:
#
# * Capa Flatten.
# * 2 capas ocultas densas con 16 y 32 neuronas respectivamente, ambas con función de activación ReLu.
# * 1 capa de salida con 1 neurona y función de activación sigmoide ("sigmoid").
#
# **PREGUNTAS:**
# * ¿Cuántos parámetros debe ajustar el modelo en total?

# %%
exercise3_input_layer = layers.Input(shape=(256, 256, 3))

exercise3_layer_conv_1 = layers.Conv2D(filters=16, kernel_size=(3, 3), strides=(1, 1), padding="same",
                                       activation="relu")(exercise3_input_layer)
exercise3_layer_conv_2 = layers.Conv2D(filters=32, kernel_size=(5, 5), strides=(2, 2), padding="valid",
                                       activation="relu")(exercise3_layer_conv_1)

exercise3_pool = layers.MaxPool2D(pool_size=(2, 2))(exercise3_layer_conv_2)

exercise3_flatten = layers.Flatten()(exercise3_pool)

exercise3_dense_hidden_1 = layers.Dense(16, activation='relu')(exercise3_flatten)
exercise3_dense_hidden_2 = layers.Dense(32, activation='relu')(exercise3_dense_hidden_1)

exercise3_dense_output = layers.Dense(1, activation='sigmoid')(exercise3_dense_hidden_2)

exercise3_model = Model(inputs=[exercise3_input_layer], outputs=[exercise3_dense_output])

exercise3_model.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  conv2d_6 (Conv2D)           (None, 256, 256, 16)      448
#
#  conv2d_7 (Conv2D)           (None, 126, 126, 32)      12832
#
#  max_pooling2d_3 (MaxPoolin  (None, 63, 63, 32)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 127008)            0
#
#  dense (Dense)               (None, 16)                2032144
#
#  dense_1 (Dense)             (None, 32)                544
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2046001 (7.80 MB)
# Trainable params: 2046001 (7.80 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# - El modelo debe ajustar 2_046_001 parametros

# %% [markdown]
# ## Ejercicio 4
#
# Implementa la misma arquitectura que en el Ejercicio 3 pero emplea una capa GlobalAveragePooling2D en lugar de Flatten.
#
# **PREGUNTAS:**
# * ¿Cuántos parámetros debe ajustar el modelo en total?

# %%
exercise4_input_layer = layers.Input(shape=(256, 256, 3))

exercise4_layer_conv_1 = layers.Conv2D(filters=16, kernel_size=(3, 3), strides=(1, 1), padding="same",
                                       activation="relu")(exercise4_input_layer)
exercise4_layer_conv_2 = layers.Conv2D(filters=32, kernel_size=(5, 5), strides=(2, 2), padding="valid",
                                       activation="relu")(exercise4_layer_conv_1)

exercise4_pool = layers.MaxPool2D(pool_size=(2, 2))(exercise4_layer_conv_2)

exercise4_global_avg = layers.GlobalAveragePooling2D()(exercise4_pool)

exercise4_dense_hidden_1 = layers.Dense(16, activation='relu')(exercise4_global_avg)
exercise4_dense_hidden_2 = layers.Dense(32, activation='relu')(exercise4_dense_hidden_1)

exercise4_dense_output = layers.Dense(1, activation='sigmoid')(exercise4_dense_hidden_2)

exercise4_model = Model(inputs=[exercise4_input_layer], outputs=[exercise4_dense_output])

exercise4_model.summary()
# Out:
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  conv2d_8 (Conv2D)           (None, 256, 256, 16)      448
#
#  conv2d_9 (Conv2D)           (None, 126, 126, 32)      12832
#
#  max_pooling2d_4 (MaxPoolin  (None, 63, 63, 32)        0
#  g2D)
#
#  global_average_pooling2d_1  (None, 32)                0
#   (GlobalAveragePooling2D)
#
#  dense_3 (Dense)             (None, 16)                528
#
#  dense_4 (Dense)             (None, 32)                544
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 14385 (56.19 KB)
# Trainable params: 14385 (56.19 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# - El modelo debe ajustar un total de 14_385 parametros

# %% [markdown]
# # Parte III: Red Neuronal Convolucional (CNN)
#
# En esta parte de la sesión vamos a cargar una base de datos, implementar una arquitectura y entrenarla para resolver un problema de clasificación.
#
# Para ello, vamos a hacer uso de una base de datos formada por perros y gatos y vemos a tratar de entrenar un modelo de clasificación que sea capaz de diferenciar ambas clases.
#
# El principal objetivo de esta parte es entender correctamente como cargar una base de datos y prepararla, como implementar una arquitectura y como realizar el ajuste de la misma, por lo tanto, no nos centraremos tanto en conseguir buenos resultados.

# %%
import tensorflow as tf
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt

# %%
# from google.colab import drive
# 
# drive.mount('/content/drive')
# 
# root_path = Path('drive/My Drive/mislata_ia_imagenes/')

# %%
# _URL = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip'
# path_to_zip = tf.keras.utils.get_file('cats_and_dogs_filtered.zip', origin=_URL, extract=True)

# %%
path_to_zip = './cats_and_dogs_filtered'

# %%
print(path_to_zip)
# Out:
# ./cats_and_dogs_filtered

# %%
# Convertimos directorio a directorio de pathlib
path_to_zip = Path(path_to_zip)
path_datasets = path_to_zip.parent
print(list(path_datasets.iterdir()))
path_dataset = path_datasets / 'cats_and_dogs_filtered'
print('Contenido carpeta descargada: ', list(path_dataset.iterdir()))
# Out:
# [WindowsPath('cats_and_dogs_filtered'), WindowsPath('imagen2.jpeg'), WindowsPath('Unit03-Exercise.ipynb'), WindowsPath('Unit03-SampleNotebook.ipynb')]
# Contenido carpeta descargada:  [WindowsPath('cats_and_dogs_filtered/train'), WindowsPath('cats_and_dogs_filtered/validation'), WindowsPath('cats_and_dogs_filtered/vectorize.py')]

# %%
path_train = path_dataset / 'train'
path_val = path_dataset / 'validation'

print('Contenido carpeta entrenamiento: ')
print(list(path_train.iterdir()))
print('Contenido carpeta validación: ')
print(list(path_val.iterdir()))
# Out:
# Contenido carpeta entrenamiento:
# [WindowsPath('cats_and_dogs_filtered/train/cats'), WindowsPath('cats_and_dogs_filtered/train/dogs')]
# Contenido carpeta validación:
# [WindowsPath('cats_and_dogs_filtered/validation/cats'), WindowsPath('cats_and_dogs_filtered/validation/dogs')]

# %%
path_dogs_train = path_train / 'dogs'
list(path_dogs_train.iterdir())
# Out:
# [WindowsPath('cats_and_dogs_filtered/train/dogs/dog.0.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.1.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.10.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.100.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.101.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.102.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.103.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.104.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.105.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.106.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.107.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.108.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.109.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.11.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.110.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.111.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.112.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.113.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.114.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.115.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.116.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.117.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.118.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.119.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.12.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.120.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.121.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.122.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.123.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.124.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.125.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.126.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.127.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.128.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.129.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.13.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.130.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.131.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.132.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.133.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.134.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.135.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.136.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.137.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.138.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.139.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.14.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.140.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.141.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.142.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.143.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.144.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.145.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.146.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.147.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.148.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.149.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.15.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.150.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.151.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.152.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.153.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.154.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.155.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.156.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.157.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.158.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.159.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.16.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.160.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.161.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.162.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.163.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.164.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.165.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.166.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.167.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.168.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.169.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.17.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.170.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.171.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.172.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.173.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.174.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.175.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.176.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.177.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.178.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.179.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.18.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.180.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.181.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.182.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.183.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.184.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.185.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.186.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.187.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.188.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.189.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.19.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.190.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.191.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.192.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.193.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.194.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.195.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.196.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.197.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.198.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.199.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.2.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.20.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.200.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.201.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.202.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.203.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.204.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.205.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.206.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.207.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.208.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.209.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.21.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.210.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.211.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.212.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.213.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.214.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.215.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.216.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.217.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.218.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.219.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.22.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.220.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.221.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.222.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.223.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.224.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.225.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.226.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.227.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.228.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.229.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.23.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.230.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.231.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.232.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.233.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.234.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.235.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.236.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.237.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.238.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.239.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.24.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.240.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.241.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.242.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.243.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.244.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.245.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.246.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.247.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.248.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.249.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.25.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.250.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.251.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.252.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.253.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.254.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.255.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.256.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.257.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.258.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.259.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.26.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.260.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.261.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.262.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.263.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.264.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.265.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.266.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.267.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.268.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.269.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.27.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.270.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.271.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.272.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.273.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.274.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.275.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.276.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.277.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.278.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.279.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.28.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.280.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.281.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.282.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.283.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.284.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.285.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.286.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.287.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.288.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.289.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.29.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.290.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.291.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.292.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.293.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.294.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.295.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.296.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.297.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.298.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.299.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.3.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.30.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.300.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.301.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.302.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.303.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.304.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.305.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.306.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.307.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.308.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.309.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.31.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.310.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.311.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.312.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.313.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.314.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.315.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.316.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.317.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.318.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.319.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.32.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.320.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.321.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.322.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.323.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.324.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.325.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.326.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.327.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.328.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.329.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.33.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.330.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.331.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.332.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.333.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.334.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.335.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.336.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.337.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.338.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.339.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.34.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.340.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.341.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.342.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.343.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.344.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.345.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.346.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.347.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.348.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.349.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.35.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.350.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.351.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.352.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.353.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.354.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.355.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.356.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.357.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.358.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.359.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.36.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.360.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.361.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.362.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.363.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.364.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.365.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.366.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.367.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.368.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.369.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.37.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.370.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.371.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.372.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.373.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.374.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.375.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.376.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.377.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.378.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.379.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.38.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.380.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.381.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.382.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.383.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.384.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.385.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.386.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.387.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.388.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.389.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.39.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.390.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.391.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.392.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.393.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.394.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.395.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.396.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.397.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.398.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.399.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.4.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.40.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.400.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.401.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.402.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.403.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.404.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.405.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.406.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.407.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.408.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.409.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.41.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.410.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.411.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.412.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.413.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.414.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.415.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.416.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.417.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.418.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.419.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.42.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.420.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.421.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.422.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.423.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.424.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.425.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.426.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.427.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.428.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.429.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.43.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.430.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.431.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.432.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.433.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.434.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.435.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.436.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.437.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.438.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.439.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.44.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.440.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.441.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.442.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.443.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.444.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.445.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.446.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.447.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.448.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.449.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.45.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.450.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.451.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.452.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.453.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.454.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.455.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.456.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.457.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.458.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.459.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.46.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.460.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.461.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.462.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.463.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.464.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.465.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.466.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.467.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.468.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.469.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.47.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.470.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.471.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.472.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.473.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.474.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.475.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.476.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.477.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.478.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.479.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.48.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.480.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.481.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.482.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.483.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.484.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.485.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.486.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.487.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.488.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.489.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.49.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.490.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.491.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.492.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.493.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.494.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.495.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.496.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.497.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.498.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.499.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.5.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.50.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.500.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.501.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.502.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.503.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.504.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.505.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.506.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.507.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.508.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.509.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.51.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.510.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.511.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.512.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.513.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.514.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.515.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.516.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.517.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.518.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.519.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.52.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.520.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.521.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.522.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.523.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.524.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.525.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.526.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.527.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.528.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.529.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.53.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.530.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.531.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.532.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.533.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.534.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.535.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.536.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.537.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.538.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.539.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.54.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.540.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.541.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.542.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.543.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.544.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.545.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.546.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.547.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.548.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.549.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.55.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.550.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.551.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.552.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.553.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.554.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.555.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.556.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.557.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.558.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.559.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.56.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.560.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.561.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.562.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.563.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.564.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.565.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.566.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.567.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.568.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.569.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.57.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.570.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.571.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.572.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.573.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.574.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.575.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.576.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.577.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.578.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.579.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.58.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.580.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.581.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.582.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.583.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.584.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.585.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.586.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.587.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.588.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.589.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.59.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.590.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.591.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.592.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.593.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.594.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.595.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.596.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.597.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.598.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.599.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.6.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.60.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.600.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.601.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.602.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.603.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.604.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.605.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.606.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.607.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.608.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.609.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.61.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.610.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.611.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.612.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.613.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.614.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.615.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.616.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.617.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.618.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.619.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.62.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.620.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.621.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.622.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.623.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.624.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.625.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.626.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.627.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.628.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.629.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.63.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.630.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.631.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.632.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.633.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.634.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.635.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.636.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.637.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.638.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.639.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.64.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.640.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.641.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.642.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.643.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.644.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.645.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.646.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.647.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.648.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.649.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.65.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.650.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.651.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.652.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.653.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.654.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.655.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.656.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.657.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.658.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.659.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.66.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.660.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.661.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.662.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.663.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.664.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.665.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.666.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.667.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.668.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.669.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.67.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.670.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.671.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.672.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.673.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.674.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.675.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.676.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.677.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.678.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.679.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.68.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.680.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.681.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.682.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.683.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.684.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.685.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.686.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.687.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.688.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.689.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.69.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.690.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.691.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.692.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.693.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.694.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.695.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.696.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.697.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.698.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.699.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.7.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.70.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.700.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.701.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.702.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.703.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.704.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.705.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.706.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.707.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.708.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.709.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.71.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.710.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.711.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.712.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.713.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.714.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.715.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.716.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.717.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.718.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.719.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.72.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.720.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.721.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.722.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.723.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.724.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.725.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.726.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.727.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.728.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.729.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.73.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.730.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.731.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.732.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.733.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.734.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.735.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.736.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.737.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.738.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.739.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.74.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.740.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.741.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.742.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.743.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.744.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.745.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.746.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.747.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.748.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.749.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.75.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.750.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.751.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.752.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.753.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.754.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.755.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.756.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.757.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.758.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.759.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.76.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.760.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.761.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.762.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.763.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.764.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.765.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.766.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.767.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.768.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.769.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.77.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.770.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.771.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.772.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.773.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.774.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.775.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.776.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.777.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.778.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.779.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.78.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.780.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.781.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.782.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.783.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.784.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.785.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.786.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.787.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.788.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.789.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.79.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.790.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.791.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.792.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.793.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.794.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.795.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.796.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.797.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.798.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.799.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.8.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.80.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.800.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.801.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.802.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.803.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.804.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.805.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.806.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.807.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.808.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.809.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.81.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.810.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.811.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.812.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.813.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.814.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.815.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.816.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.817.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.818.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.819.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.82.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.820.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.821.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.822.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.823.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.824.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.825.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.826.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.827.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.828.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.829.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.83.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.830.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.831.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.832.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.833.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.834.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.835.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.836.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.837.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.838.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.839.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.84.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.840.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.841.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.842.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.843.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.844.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.845.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.846.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.847.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.848.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.849.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.85.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.850.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.851.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.852.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.853.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.854.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.855.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.856.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.857.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.858.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.859.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.86.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.860.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.861.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.862.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.863.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.864.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.865.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.866.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.867.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.868.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.869.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.87.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.870.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.871.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.872.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.873.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.874.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.875.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.876.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.877.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.878.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.879.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.88.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.880.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.881.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.882.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.883.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.884.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.885.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.886.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.887.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.888.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.889.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.89.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.890.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.891.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.892.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.893.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.894.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.895.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.896.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.897.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.898.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.899.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.9.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.90.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.900.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.901.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.902.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.903.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.904.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.905.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.906.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.907.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.908.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.909.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.91.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.910.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.911.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.912.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.913.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.914.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.915.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.916.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.917.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.918.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.919.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.92.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.920.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.921.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.922.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.923.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.924.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.925.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.926.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.927.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.928.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.929.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.93.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.930.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.931.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.932.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.933.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.934.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.935.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.936.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.937.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.938.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.939.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.94.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.940.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.941.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.942.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.943.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.944.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.945.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.946.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.947.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.948.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.949.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.95.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.950.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.951.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.952.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.953.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.954.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.955.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.956.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.957.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.958.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.959.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.96.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.960.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.961.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.962.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.963.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.964.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.965.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.966.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.967.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.968.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.969.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.97.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.970.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.971.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.972.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.973.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.974.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.975.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.976.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.977.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.978.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.979.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.98.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.980.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.981.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.982.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.983.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.984.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.985.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.986.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.987.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.988.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.989.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.99.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.990.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.991.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.992.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.993.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.994.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.995.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.996.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.997.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.998.jpg'),
#  WindowsPath('cats_and_dogs_filtered/train/dogs/dog.999.jpg')]

# %% [markdown]
# # **Cargado de las imágnes en lotes**
#
# Para esto vamos a hacer uso del método de Tensorflow/Keras image_dataset_from_directory. Este método facilita la creación de datasets legibles por Tensorflow. Solo necesitamos tener las imágenes en nuestro sistema de archivos ordenadas de manera apropiada. Esto es, las imágenes pertenecientes a cada clase en una carpeta diferente. No es necesario tener carpeta de entrenamiento y validación, podemos crear posteriormente las particiones si todas las imágenes se encuentran en una única carpeta.
#
# En este método las etiquetas son inferidas, es decir, genera lotes de imágenes de los subdirectorios dentro de la carpeta, asignándoles etiquetas diferentes (cats -> 0, dogs -> 1). Si no se especifica de otra forma, la asignación de etiquetas se realiza en orden alfabético.

# %%
from tensorflow.keras.preprocessing import image_dataset_from_directory

n_rows = 160
n_cols = 160

# A diferencia del método anterior, aquí ya tenemos que especificar el tamaño del lote que se va a emplear durante el entrenamiento
BATCH_SIZE = 32

# El argumento "shuffle" a True hace que las imágenes se carguen y se reordenen de forma aleatoria
# Por lo que este paso ya no hará falta que lo hagamos manualmente como antes
train_dataset = image_dataset_from_directory(
    path_train,
    shuffle=True,
    seed=123,
    batch_size=BATCH_SIZE,
    image_size=(n_rows, n_cols)
)

validation_dataset = image_dataset_from_directory(
    path_val,
    shuffle=True,
    seed=123,
    batch_size=BATCH_SIZE,
    image_size=(n_rows, n_cols)
)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.

# %% [markdown]
# Podemos ver que el método ha encontrado el número de imágenes y etiquetas esperado tanto para el conjunto de datos de entrenamiento como el de validación

# %%
class_names = train_dataset.class_names
print('Etiquetas encontradas: ', class_names)
# Out:
# Etiquetas encontradas:  ['cats', 'dogs']

# %%
plt.figure(figsize=(10, 10))
# En un dataset creado de la forma anterior podemos emplear el método "take" para coger n número de lotes. En nuestro caso vamos a coger 1
for images, labels in train_dataset.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        if labels[i] == 0:
            plt.title('Gato')
        elif labels[i] == 1:
            plt.title('Perro')
        plt.axis("off")

# %% [markdown]
# En este punto ya hemos cargado las imágenes, las hemos redimensionado y las hemos reordenados para que tengan un orden aleatorio (en muchas menos líneas de código!!), nos queda generar las particiones de entrenamiento, validación y test y realizar el escalado.
#
# En primer lugar vamos a generar las 3 particiones dividiendo, como hicimos en el otro caso, el conjunto de validación en dos particiones (validación y test)

# %%
# Obtenemos cuantos lotes tiene la partición original de validación
val_batches = tf.data.experimental.cardinality(validation_dataset)
print('Número de lotes de validación original: ', val_batches.numpy())

# Asignamos la mitad a cada partición
test_dataset = validation_dataset.take(val_batches // 2)  # Cogemos la mitad
validation_dataset = validation_dataset.skip(val_batches // 2)  # Eliminamos la mitad
print('Número de lotes de validación: ', tf.data.experimental.cardinality(validation_dataset).numpy())
print('Número de lotes de test: ', tf.data.experimental.cardinality(test_dataset).numpy())
# Out:
# Número de lotes de validación original:  32
# Número de lotes de validación:  16
# Número de lotes de test:  16

# %%
# Obtenemos numero de lotes que forman la partición de entrenamiento
train_batches = tf.data.experimental.cardinality(train_dataset)
print('Número de lotes de entrenamiento: ', train_batches.numpy())
# Out:
# Número de lotes de entrenamiento:  63

# %% [markdown]
# El siguiente bloque de código se añade por defecto cuando queramos leer imágenes del sistema de archivos de manera dinámica para evitar que la E/S se bloquee. Permite mejorar el rendimiento en la carga de datos.

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# Finalmente, realizamos el escalado de las imágenes. En este punto, nos encontramos con un inconveniente, y es que las aproximaciones featurewise no las podemos aplicar en este caso (a no ser que calculemos la media y desviación estándar de manera independiente), ya que en memoria únicamente vamos a tener cargado 1 lote simultáneamente.
#
# El resto de escalados si que podremos aplicarlos, vamos a ver como.

# %%
# Vamos a ver valores de intensidad mínimo y máximo de una imagen antes de realizar el escalado
for images, labels in train_dataset.take(1):
    print('Intensidad mínima: ', images[0].numpy().min())
    print('Intensidad máxima: ', images[0].numpy().max())
# Out:
# Intensidad mínima:  0.0
# Intensidad máxima:  248.125

# %%
# Vamos a hacer uso de la función "map" que aplica a cada registro dentro del dataset la transformación que nosotros definamos, en nuestro caso "scaling"
# A la función que llamemos con "map" siempre le van a entrar los mismos dos argumentos: "image" y "label".

def scaling_normalization(image, label):
    image = tf.cast(image / 255., tf.float32)
    return image, label


train_dataset = train_dataset.map(scaling_normalization)
validation_dataset = validation_dataset.map(scaling_normalization)
test_dataset = test_dataset.map(scaling_normalization)

# %%
# Vemos nuevos valores de intensidad mínimo y máximo tras realizar el escalado
for images, labels in train_dataset.take(1):
    print('Intensidad mínima: ', images[0].numpy().min())
    print('Intensidad máxima: ', images[0].numpy().max())
# Out:
# Intensidad mínima:  0.0
# Intensidad máxima:  1.0

# %% [markdown]
# # **Definición de la arquitectura**
#
# Una vez tenemos los datos listos podemos proceder a definir la arquitectura a entrenar. En primer lugar tenemos que definir el conjunto de capas que forman nuestra arquitectura.

# %% [markdown]
# ## Ejercicio 5
#
# Implementa una arquitectura que se ajuste al siguiente "summary" donde el tamaño de los filtros convolucionales es de 3x3 y se emplea una función de activación de tipo ReLU en dichos filtros.
# En la capa densa oculta también se emplea una función de activación ReLU.
# Finalmente, en la capa densa de salida, se hace uso de la función de activación sigmoide ("sigmoid").

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def create_model():
    exercise5_input_layer = layers.Input(shape=(160, 160, 3))

    exercise5_layer_conv_1 = layers.Conv2D(filters=16, kernel_size=(3, 3), strides=(1, 1), padding="same",
                                           activation="relu")(exercise5_input_layer)

    exercise5_pool_1 = layers.MaxPool2D(pool_size=(2, 2))(exercise5_layer_conv_1)

    exercise5_layer_conv_2 = layers.Conv2D(filters=32, kernel_size=(3, 3), strides=(1, 1), padding="same",
                                           activation="relu")(exercise5_pool_1)

    exercise5_pool_2 = layers.MaxPool2D(pool_size=(2, 2))(exercise5_layer_conv_2)

    exercise5_layer_conv_3 = layers.Conv2D(filters=64, kernel_size=(3, 3), strides=(1, 1), padding="same",
                                           activation="relu")(exercise5_pool_2)

    exercise5_flatten = layers.Flatten()(exercise5_layer_conv_3)

    exercise5_dense_hidden_1 = layers.Dense(32, activation='relu')(exercise5_flatten)

    exercise5_dense_output = layers.Dense(1, activation='sigmoid')(exercise5_dense_hidden_1)

    exercise5_model = Model(inputs=[exercise5_input_layer], outputs=[exercise5_dense_output])

    return exercise5_model

# %%
model_base = create_model()
model_base.summary()
# Out:
# WARNING:tensorflow:From C:\Users\JulianBSL\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# WARNING:tensorflow:From C:\Users\JulianBSL\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 160, 160, 3)]     0
#
#  conv2d (Conv2D)             (None, 160, 160, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 80, 80, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 80, 80, 32)        4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 40, 40, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 40, 40, 64)        18496
#
#  flatten (Flatten)           (None, 102400)            0
#
#  dense (Dense)               (None, 32)                3276832
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 3300449 (12.59 MB)
# Trainable params: 3300449 (12.59 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Compilación y entrenamiento
#
# Ya tenemos la arquitectura definida, para poder inicializar el entrenamiento solo nos queda definir la tasa de aprendizaje, la función de coste y las métricas.
# La tasa de aprendizaje la definiremos a través de argumento "optimizer", la función de coste a través del argumento "loss" y las métricas irán definidas dentro de una lista y se definirán a través del argumento "metrics".
#
# - Como tasa de aprendizaje vamos a emplear el optimizador Adam con sus parámetros definidos por defecto, esto lo podremos definir a través de la palabra clave "adam" ya que es algo que Keras entiende internamente.
# - Como función de pérdidas, al tratarse de un problema de clasificación binaria emplearemos la entropía cruzada binaria. Para esto Keras también tiene la palabra clave: "binary_crossentropy".
# - Como métricas, al tratarse de un problema de clasificación, la métrica que más nos interesa es la exactitud (accuracy en inglés). Para esto también haremos uso de la palabra clave "accuracy".

# %%
model_base.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\JulianBSL\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %% [markdown]
# Finalmente, ya podemos pasar a realizar el entrenamiento del modelo, para ello vamos a hacer uso del método "fit".
#
# Durante el entrenamiento vamos a emplear un "callback" de Keras que nos va a ser de gran utilidad y que emplearemos **SIEMPRE** cuando entrenemos un modelo.
#
# Se trata del callback [ModelCheckpoint](https://keras.io/api/callbacks/model_checkpoint/). Este permite almacenar el modelo en ciertos puntos del entrenamiento. Nosotros lo vamos a emplear para almacenar el modelo en el que tengamos las mejores métricas de validación.
#
# Vamos a crearnos una carpeta para el experimento que estamos realizando donde se almacenará dicho modelo. Para organizar todos los experimentos que habamos vamos a crearnos la carpeta "models" y dentro de esta, crearemos la carpeta "Train1" donde guardaremos los resultados del experimento actual.

# %%
root_path = Path('.')

# %%
path_project = root_path / 'dogs_cats'
path_models = path_project / 'models'
path_experiment = path_models / 'Train1'

path_experiment.mkdir(exist_ok=True, parents=True)

# %%
# Inicializamos el callback
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='./dogs_and_cats.h5',
    monitor='val_accuracy',
    mode='max',
    save_best_only=True,
    verbose=1)

# Entrenamos
history_model_base = model_base.fit(train_dataset,
                                    epochs=10,
                                    validation_data=validation_dataset,
                                    callbacks=[model_checkpoint_callback],
                                    verbose=False)
# Out:
# Epoch 1: val_accuracy improved from -inf to 0.70287, saving model to .\dogs_and_cats.h5
#
# Epoch 2: val_accuracy did not improve from 0.70287
#
# Epoch 3: val_accuracy improved from 0.70287 to 0.70697, saving model to .\dogs_and_cats.h5
#
# Epoch 4: val_accuracy did not improve from 0.70697
#
# Epoch 5: val_accuracy did not improve from 0.70697
#
# Epoch 6: val_accuracy did not improve from 0.70697
#
# Epoch 7: val_accuracy did not improve from 0.70697
#
# Epoch 8: val_accuracy did not improve from 0.70697
#
# Epoch 9: val_accuracy did not improve from 0.70697
#
# Epoch 10: val_accuracy did not improve from 0.70697

# %% [markdown]
# En la carpeta que hemos creado también vamos a almacenar la historia. Esto nos será de ayuda si en cualquier momento queremos revisar los resultados de un experimento dado.

# %%
np.save(path_experiment / 'history.npy', history_model_base.history)

# %% [markdown]
# Visualizamos los resultados

# %%
# Método para la visualización de la exactitud obtenida durante el proceso de entrenamiento tanto en entrenamiento como en validación
def plot_losses(history):
    plt.plot(history.history['loss'], label="Entrenamiento")
    plt.plot(history.history['val_loss'], label="Validación")
    plt.ylabel('Pérdidas')
    plt.xlabel('Época')
    plt.legend(loc="upper right")
    plt.title('Pérdidas durante el entrenamiento')


# Método para la visualización de la exactitud obtenida durante el proceso de entrenamiento tanto en entrenamiento como en validación
def plot_accuracy(history):
    plt.plot(history.history['accuracy'], label="Entrenamiento")
    plt.plot(history.history['val_accuracy'], label="Validación")
    plt.ylabel('Exactitud')
    plt.xlabel('Época')
    plt.legend(loc="upper right")
    plt.title('Exactitud durante el entrenamiento')

# %%
plot_losses(history_model_base)

# %%
plot_accuracy(history_model_base)

# %% [markdown]
# **¿Qué podemos interpretar de las gráficas anteriores?**

# %% [markdown]
# Finalmente, evaluamos el modelo entrenado sobre la base de datos de test. Si empleamos el modelo que tenemos ahora mismo cargado en memoria (model_base), estaremos evaluando el modelo correspondiente a la última época. Por lo tanto, para evaluar aquel que mejor resultado en validación nos ha dado vamos a cargarlo previamente.

# %%
# Cargamos el modelo
model_base = tf.keras.models.load_model('./dogs_and_cats.h5')

# %%
# Extraemos métricas test
_, acc_base = model_base.evaluate(test_dataset, verbose=0)
print('Exactitud test: ', acc_base)
# Out:
# Exactitud test:  0.68359375

# %% [markdown]
# # Experimentación

# %% [markdown]
# ## Ejercicio 6
#
# Implementa una arquitectura que responda al siguiente summary.
# * Filtros convolucionales de 3x3 con función de activación ReLU.
# * Capa densa oculta con función de activacuón ReLU.
# * Capa densa de salida con función de activación Sigmoide.
#
# **PISTA**: Con respecto a la arquitectura que hemos empleado antes solo hay un pequeño cambio en los filtros convolucionales.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
exercise6_input_layer = layers.Input(shape=(160, 160, 3))

exercise6_layer_conv_1 = layers.Conv2D(filters=16, kernel_size=(3, 3), strides=(1, 1), padding="valid",
                                       activation="relu")(exercise6_input_layer)

exercise6_pool_1 = layers.MaxPool2D(pool_size=(2, 2))(exercise6_layer_conv_1)

exercise6_layer_conv_2 = layers.Conv2D(filters=32, kernel_size=(3, 3), strides=(1, 1), padding="valid",
                                       activation="relu")(exercise6_pool_1)

exercise6_pool_2 = layers.MaxPool2D(pool_size=(2, 2))(exercise6_layer_conv_2)

exercise6_layer_conv_3 = layers.Conv2D(filters=64, kernel_size=(3, 3), strides=(1, 1), padding="valid",
                                       activation="relu")(exercise6_pool_2)

exercise6_flatten = layers.Flatten()(exercise6_layer_conv_3)

exercise6_dense_hidden_1 = layers.Dense(32, activation='relu')(exercise6_flatten)

exercise6_dense_output = layers.Dense(1, activation='sigmoid')(exercise6_dense_hidden_1)

exercise6_model = Model(inputs=[exercise6_input_layer], outputs=[exercise6_dense_output])

exercise6_model.compile(optimizer="adam")
exercise6_model.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 160, 160, 3)]     0
#
#  conv2d_15 (Conv2D)          (None, 158, 158, 16)      448
#
#  max_pooling2d_10 (MaxPooli  (None, 79, 79, 16)        0
#  ng2D)
#
#  conv2d_16 (Conv2D)          (None, 77, 77, 32)        4640
#
#  max_pooling2d_11 (MaxPooli  (None, 38, 38, 32)        0
#  ng2D)
#
#  conv2d_17 (Conv2D)          (None, 36, 36, 64)        18496
#
#  flatten_5 (Flatten)         (None, 82944)             0
#
#  dense_10 (Dense)            (None, 32)                2654240
#
#  dense_11 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 2677857 (10.22 MB)
# Trainable params: 2677857 (10.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Ejercicio 7
#
# Implementa una arquitectura que responda al siguiente summary.
# * Filtros convolucionales de 3x3 con función de activación ReLU.
# * Capa densa oculta con función de activacuón ReLU.
# * Capa densa de salida con función de activación Sigmoide.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
exercise7_input_layer = layers.Input(shape=(160, 160, 3))

exercise7_layer_conv_1 = layers.Conv2D(filters=16, kernel_size=(3, 3), strides=(1, 1), padding="same",
                                       activation="relu")(exercise7_input_layer)
exercise7_layer_conv_2 = layers.Conv2D(filters=16, kernel_size=(3, 3), strides=(1, 1), padding="valid",
                                       activation="relu")(exercise7_layer_conv_1)

exercise7_pool_1 = layers.MaxPool2D(pool_size=(2, 2))(exercise7_layer_conv_2)

exercise7_layer_conv_3 = layers.Conv2D(filters=32, kernel_size=(3, 3), strides=(1, 1), padding="same",
                                       activation="relu")(exercise7_pool_1)
exercise7_layer_conv_4 = layers.Conv2D(filters=32, kernel_size=(3, 3), strides=(1, 1), padding="valid",
                                       activation="relu")(exercise7_layer_conv_3)

exercise7_pool_2 = layers.MaxPool2D(pool_size=(2, 2))(exercise7_layer_conv_4)

exercise7_layer_conv_5 = layers.Conv2D(filters=64, kernel_size=(3, 3), strides=(1, 1), padding="same",
                                       activation="relu")(exercise7_pool_2)
exercise7_layer_conv_6 = layers.Conv2D(filters=64, kernel_size=(3, 3), strides=(1, 1), padding="valid",
                                       activation="relu")(exercise7_layer_conv_5)

exercise7_flatten = layers.Flatten()(exercise7_layer_conv_6)

exercise7_dense_hidden_1 = layers.Dense(32, activation='relu')(exercise7_flatten)

exercise7_dense_output = layers.Dense(1, activation='sigmoid')(exercise7_dense_hidden_1)

exercise7_model = Model(inputs=[exercise7_input_layer], outputs=[exercise7_dense_output])

exercise7_model.compile(optimizer="adam")
exercise7_model.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 160, 160, 3)]     0
#
#  conv2d_18 (Conv2D)          (None, 160, 160, 16)      448
#
#  conv2d_19 (Conv2D)          (None, 158, 158, 16)      2320
#
#  max_pooling2d_12 (MaxPooli  (None, 79, 79, 16)        0
#  ng2D)
#
#  conv2d_20 (Conv2D)          (None, 79, 79, 32)        4640
#
#  conv2d_21 (Conv2D)          (None, 77, 77, 32)        9248
#
#  max_pooling2d_13 (MaxPooli  (None, 38, 38, 32)        0
#  ng2D)
#
#  conv2d_22 (Conv2D)          (None, 38, 38, 64)        18496
#
#  conv2d_23 (Conv2D)          (None, 36, 36, 64)        36928
#
#  flatten_6 (Flatten)         (None, 82944)             0
#
#  dense_12 (Dense)            (None, 32)                2654240
#
#  dense_13 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 2726353 (10.40 MB)
# Trainable params: 2726353 (10.40 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Ejercicio 8
#
# Implementa una arquitectura que responda al siguiente summary.
# * Filtros convolucionales de 3x3 con función de activación ReLU.
# * Capa densa oculta con función de activacuón ReLU.
# * Capa densa de salida con función de activación Sigmoide.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
exercise8_input_layer = layers.Input(shape=(160, 160, 3))

exercise8_layer_conv_1 = layers.Conv2D(filters=16, kernel_size=(3, 3), strides=(1, 1), padding="same",
                                       activation="relu")(exercise8_input_layer)
exercise8_layer_conv_2 = layers.Conv2D(filters=16, kernel_size=(3, 3), strides=(1, 1), padding="same",
                                       activation="relu")(exercise8_layer_conv_1)

exercise8_pool_1 = layers.MaxPool2D(pool_size=(2, 2))(exercise8_layer_conv_2)

exercise8_layer_conv_3 = layers.Conv2D(filters=32, kernel_size=(3, 3), strides=(1, 1), padding="same",
                                       activation="relu")(exercise8_pool_1)
exercise8_layer_conv_4 = layers.Conv2D(filters=32, kernel_size=(3, 3), strides=(1, 1), padding="same",
                                       activation="relu")(exercise8_layer_conv_3)

exercise8_pool_2 = layers.MaxPool2D(pool_size=(2, 2))(exercise8_layer_conv_4)

exercise8_layer_conv_5 = layers.Conv2D(filters=64, kernel_size=(3, 3), strides=(1, 1), padding="same",
                                       activation="relu")(exercise8_pool_2)
exercise8_layer_conv_6 = layers.Conv2D(filters=64, kernel_size=(3, 3), strides=(1, 1), padding="same",
                                       activation="relu")(exercise8_layer_conv_5)

exercise8_flatten = layers.Flatten()(exercise8_layer_conv_6)

exercise8_dense_hidden_1 = layers.Dense(32, activation='relu')(exercise8_flatten)

exercise8_dense_output = layers.Dense(1, activation='sigmoid')(exercise8_dense_hidden_1)

exercise8_model = Model(inputs=[exercise8_input_layer], outputs=[exercise8_dense_output])

exercise8_model.compile(optimizer="adam")
exercise8_model.summary()
# Out:
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 160, 160, 3)]     0
#
#  conv2d_24 (Conv2D)          (None, 160, 160, 16)      448
#
#  conv2d_25 (Conv2D)          (None, 160, 160, 16)      2320
#
#  max_pooling2d_14 (MaxPooli  (None, 80, 80, 16)        0
#  ng2D)
#
#  conv2d_26 (Conv2D)          (None, 80, 80, 32)        4640
#
#  conv2d_27 (Conv2D)          (None, 80, 80, 32)        9248
#
#  max_pooling2d_15 (MaxPooli  (None, 40, 40, 32)        0
#  ng2D)
#
#  conv2d_28 (Conv2D)          (None, 40, 40, 64)        18496
#
#  conv2d_29 (Conv2D)          (None, 40, 40, 64)        36928
#
#  flatten_7 (Flatten)         (None, 102400)            0
#
#  dense_14 (Dense)            (None, 32)                3276832
#
#  dense_15 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 3348945 (12.78 MB)
# Trainable params: 3348945 (12.78 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Ejercicio 9
#
# Implementa una arquitectura que responda al siguiente summary.
# * Filtros convolucionales de 3x3 con función de activación ReLU.
# * Capa densa oculta con función de activacuón ReLU.
# * Capa densa de salida con función de activación Sigmoide.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
exercise9_input_layer = layers.Input(shape=(160, 160, 3))

exercise9_layer_conv_1 = layers.Conv2D(filters=128, kernel_size=(3, 3), strides=(1, 1), padding="same",
                                       activation="relu")(exercise9_input_layer)
exercise9_layer_conv_2 = layers.Conv2D(filters=128, kernel_size=(3, 3), strides=(1, 1), padding="same",
                                       activation="relu")(exercise9_layer_conv_1)

exercise9_pool_1 = layers.MaxPool2D(pool_size=(2, 2))(exercise9_layer_conv_2)

exercise9_layer_conv_3 = layers.Conv2D(filters=256, kernel_size=(3, 3), strides=(1, 1), padding="same",
                                       activation="relu")(exercise9_pool_1)
exercise9_layer_conv_4 = layers.Conv2D(filters=256, kernel_size=(3, 3), strides=(1, 1), padding="same",
                                       activation="relu")(exercise9_layer_conv_3)

exercise9_pool_2 = layers.MaxPool2D(pool_size=(2, 2))(exercise9_layer_conv_4)

exercise9_layer_conv_5 = layers.Conv2D(filters=512, kernel_size=(3, 3), strides=(1, 1), padding="same",
                                       activation="relu")(exercise9_pool_2)
exercise9_layer_conv_6 = layers.Conv2D(filters=512, kernel_size=(3, 3), strides=(1, 1), padding="same",
                                       activation="relu")(exercise9_layer_conv_5)

exercise9_flatten = layers.Flatten()(exercise9_layer_conv_6)

exercise9_dense_hidden_1 = layers.Dense(32, activation='relu')(exercise9_flatten)

exercise9_dense_output = layers.Dense(1, activation='sigmoid')(exercise9_dense_hidden_1)

exercise9_model = Model(inputs=[exercise9_input_layer], outputs=[exercise9_dense_output])

exercise9_model.compile(optimizer="adam")
exercise9_model.summary()
# Out:
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 160, 160, 3)]     0
#
#  conv2d_30 (Conv2D)          (None, 160, 160, 128)     3584
#
#  conv2d_31 (Conv2D)          (None, 160, 160, 128)     147584
#
#  max_pooling2d_16 (MaxPooli  (None, 80, 80, 128)       0
#  ng2D)
#
#  conv2d_32 (Conv2D)          (None, 80, 80, 256)       295168
#
#  conv2d_33 (Conv2D)          (None, 80, 80, 256)       590080
#
#  max_pooling2d_17 (MaxPooli  (None, 40, 40, 256)       0
#  ng2D)
#
#  conv2d_34 (Conv2D)          (None, 40, 40, 512)       1180160
#
#  conv2d_35 (Conv2D)          (None, 40, 40, 512)       2359808
#
#  flatten_8 (Flatten)         (None, 819200)            0
#
#  dense_16 (Dense)            (None, 32)                26214432
#
#  dense_17 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 30790849 (117.46 MB)
# Trainable params: 30790849 (117.46 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Ejercicio 10
#
# Implementa una arquitectura que responda al siguiente summary.
# * Filtros convolucionales de 3x3 con función de activación ReLU.
# * Capas densas ocultas con función de activacuón ReLU.
# * Capa densa de salida con función de activación Sigmoide.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
exercise10_input_layer = layers.Input(shape=(160, 160, 3))

exercise10_layer_conv_1 = layers.Conv2D(filters=128, kernel_size=(3, 3), strides=(1, 1), padding="same",
                                        activation="relu")(exercise10_input_layer)
exercise10_layer_conv_2 = layers.Conv2D(filters=128, kernel_size=(3, 3), strides=(1, 1), padding="same",
                                        activation="relu")(exercise10_layer_conv_1)

exercise10_pool_1 = layers.MaxPool2D(pool_size=(2, 2))(exercise10_layer_conv_2)

exercise10_layer_conv_3 = layers.Conv2D(filters=256, kernel_size=(3, 3), strides=(1, 1), padding="same",
                                        activation="relu")(exercise10_pool_1)
exercise10_layer_conv_4 = layers.Conv2D(filters=256, kernel_size=(3, 3), strides=(1, 1), padding="same",
                                        activation="relu")(exercise10_layer_conv_3)

exercise10_pool_2 = layers.MaxPool2D(pool_size=(2, 2))(exercise10_layer_conv_4)

exercise10_layer_conv_5 = layers.Conv2D(filters=512, kernel_size=(3, 3), strides=(1, 1), padding="same",
                                        activation="relu")(exercise10_pool_2)
exercise10_layer_conv_6 = layers.Conv2D(filters=512, kernel_size=(3, 3), strides=(1, 1), padding="same",
                                        activation="relu")(exercise10_layer_conv_5)

exercise10_flatten = layers.Flatten()(exercise10_layer_conv_6)

exercise10_dense_hidden_1 = layers.Dense(32, activation='relu')(exercise10_flatten)
exercise10_dense_hidden_2 = layers.Dense(64, activation='relu')(exercise10_dense_hidden_1)
exercise10_dense_hidden_3 = layers.Dense(128, activation='relu')(exercise10_dense_hidden_2)

exercise10_dense_output = layers.Dense(1, activation='sigmoid')(exercise10_dense_hidden_3)

exercise10_model = Model(inputs=[exercise10_input_layer], outputs=[exercise10_dense_output])

exercise10_model.compile(optimizer="adam")
exercise10_model.summary()
# Out:
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 160, 160, 3)]     0
#
#  conv2d_36 (Conv2D)          (None, 160, 160, 128)     3584
#
#  conv2d_37 (Conv2D)          (None, 160, 160, 128)     147584
#
#  max_pooling2d_18 (MaxPooli  (None, 80, 80, 128)       0
#  ng2D)
#
#  conv2d_38 (Conv2D)          (None, 80, 80, 256)       295168
#
#  conv2d_39 (Conv2D)          (None, 80, 80, 256)       590080
#
#  max_pooling2d_19 (MaxPooli  (None, 40, 40, 256)       0
#  ng2D)
#
#  conv2d_40 (Conv2D)          (None, 40, 40, 512)       1180160
#
#  conv2d_41 (Conv2D)          (None, 40, 40, 512)       2359808
#
#  flatten_9 (Flatten)         (None, 819200)            0
#
#  dense_18 (Dense)            (None, 32)                26214432
#
#  dense_19 (Dense)            (None, 64)                2112
#
#  dense_20 (Dense)            (None, 128)               8320
#
#  dense_21 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 30801377 (117.50 MB)
# Trainable params: 30801377 (117.50 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Ejercicio 11
#
# Implementa una arquitectura que responda al siguiente summary.
# * Filtros convolucionales de 3x3 con función de activación ReLU.
# * Capas densas ocultas con función de activacuón ReLU.
# * Capa densa de salida con función de activación Softmax ("softmax").

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
exercise11_input_layer = layers.Input(shape=(160, 160, 3))

exercise11_layer_conv_1 = layers.Conv2D(filters=128, kernel_size=(3, 3), strides=(1, 1), padding="same",
                                        activation="relu")(exercise11_input_layer)
exercise11_layer_conv_2 = layers.Conv2D(filters=128, kernel_size=(3, 3), strides=(1, 1), padding="same",
                                        activation="relu")(exercise11_layer_conv_1)

exercise11_pool_1 = layers.MaxPool2D(pool_size=(2, 2))(exercise11_layer_conv_2)

exercise11_layer_conv_3 = layers.Conv2D(filters=256, kernel_size=(3, 3), strides=(1, 1), padding="same",
                                        activation="relu")(exercise11_pool_1)
exercise11_layer_conv_4 = layers.Conv2D(filters=256, kernel_size=(3, 3), strides=(1, 1), padding="same",
                                        activation="relu")(exercise11_layer_conv_3)

exercise11_pool_2 = layers.MaxPool2D(pool_size=(2, 2))(exercise11_layer_conv_4)

exercise11_layer_conv_5 = layers.Conv2D(filters=512, kernel_size=(3, 3), strides=(1, 1), padding="same",
                                        activation="relu")(exercise11_pool_2)
exercise11_layer_conv_6 = layers.Conv2D(filters=512, kernel_size=(3, 3), strides=(1, 1), padding="same",
                                        activation="relu")(exercise11_layer_conv_5)

exercise11_flatten = layers.Flatten()(exercise11_layer_conv_6)

exercise11_dense_hidden_1 = layers.Dense(32, activation='relu')(exercise11_flatten)
exercise11_dense_hidden_2 = layers.Dense(64, activation='relu')(exercise11_dense_hidden_1)
exercise11_dense_hidden_3 = layers.Dense(128, activation='relu')(exercise11_dense_hidden_2)

exercise11_dense_output = layers.Dense(10, activation='softmax')(exercise11_dense_hidden_3)

exercise11_model = Model(inputs=[exercise11_input_layer], outputs=[exercise11_dense_output])

exercise11_model.compile(optimizer="adam")
exercise11_model.summary()
# Out:
# Model: "model_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 160, 160, 3)]     0
#
#  conv2d_42 (Conv2D)          (None, 160, 160, 128)     3584
#
#  conv2d_43 (Conv2D)          (None, 160, 160, 128)     147584
#
#  max_pooling2d_20 (MaxPooli  (None, 80, 80, 128)       0
#  ng2D)
#
#  conv2d_44 (Conv2D)          (None, 80, 80, 256)       295168
#
#  conv2d_45 (Conv2D)          (None, 80, 80, 256)       590080
#
#  max_pooling2d_21 (MaxPooli  (None, 40, 40, 256)       0
#  ng2D)
#
#  conv2d_46 (Conv2D)          (None, 40, 40, 512)       1180160
#
#  conv2d_47 (Conv2D)          (None, 40, 40, 512)       2359808
#
#  flatten_10 (Flatten)        (None, 819200)            0
#
#  dense_22 (Dense)            (None, 32)                26214432
#
#  dense_23 (Dense)            (None, 64)                2112
#
#  dense_24 (Dense)            (None, 128)               8320
#
#  dense_25 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 30802538 (117.50 MB)
# Trainable params: 30802538 (117.50 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
