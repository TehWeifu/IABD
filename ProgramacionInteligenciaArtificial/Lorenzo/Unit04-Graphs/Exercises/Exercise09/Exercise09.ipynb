# %% [markdown]
# Ejercicio 9: Layout
#
# Crea una figura con los siguientes subplots:

# %%
from matplotlib import pyplot as plt

# %%
figure = plt.figure(figsize=(12, 10))
figure.add_subplot(3, 1, 1)
figure.add_subplot(3, 2, 3, projection='3d')
figure.add_subplot(3, 2, 4, projection='3d')
figure.add_subplot(3, 2, 5, projection='3d')
figure.add_subplot(3, 2, 6, projection='3d')
# Out:
# <Axes3D: >

# %%
figure.suptitle('Exercise 09')
figure.savefig('./Exercise09')
