# %% [markdown]
# Ejercicio 10: tipos de gráficos 2D
# Dado las variables x e y

# %%
from matplotlib import pyplot as plt

# %%
x = [-3., -2.57142857, -2.14285714, -1.71428571, -1.28571429, -0.85714286, -0.42857143, 0., 0.42857143, 0.85714286,
     1.28571429, 1.71428571, 2.14285714, 2.57142857, 3.]
y = [0.00443185, 0.01462444, 0.04016108, 0.09178317, 0.17456307, 0.27629519, 0.36393672, 0.39894228, 0.36393672,
     0.27629519, 0.17456307, 0.09178317, 0.04016108, 0.01462444, 0.00443185]

# %% [markdown]
# Dibuja en una figura x e y como una serie de puntos.

# %%
figure1 = plt.figure()
axes1 = figure1.add_subplot()
axes1.scatter(x, y)

# %% [markdown]
# Dibuja en una figura x e y como una linea continua.

# %%
figure2 = plt.figure()
axes2 = figure2.add_subplot()
axes2.plot(x, y)

# %% [markdown]
# Dibuja en una figura x e y como un diagrama de barras.

# %%
figure3 = plt.figure()
axes3 = figure3.add_subplot()
axes3.bar(x, y)
# Out:
# <BarContainer object of 15 artists>

# %% [markdown]
# Dibuja en una figura x e y como una linea continua y además los puntos.

# %%
figure4 = plt.figure()
axes4 = figure4.add_subplot()
axes4.scatter(x, y)
axes4.plot(x, y)
