# %%
# Load breast cancer dataset

from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler

# %%
def get_data():
    data = load_breast_cancer()

    X = data.data
    y = data.target

    print()
    print(X)

    standard_scaler = StandardScaler()

    standard_scaler.mean_ = [1.41272917e+01, 1.92896485e+01, 9.19690334e+01, 6.54889104e+02,
                             9.63602812e-02, 1.04340984e-01, 8.87993158e-02, 4.89191459e-02,
                             1.81161863e-01, 6.27976098e-02, 4.05172056e-01, 1.21685343e+00,
                             2.86605923e+00, 4.03370791e+01, 7.04097891e-03, 2.54781388e-02,
                             3.18937163e-02, 1.17961371e-02, 2.05422988e-02, 3.79490387e-03,
                             1.62691898e+01, 2.56772232e+01, 1.07261213e+02, 8.80583128e+02,
                             1.32368594e-01, 2.54265044e-01, 2.72188483e-01, 1.14606223e-01,
                             2.90075571e-01, 8.39458172e-02]

    standard_scaler.var_ = [1.23970943e+01, 1.84663974e+01, 5.89402799e+02, 1.23625903e+05,
                            1.97452073e-04, 2.78428549e-03, 6.34407875e-03, 1.50301462e-03,
                            7.50222008e-04, 4.97611152e-05, 7.67671984e-02, 3.03781123e-01,
                            4.08071149e+00, 2.06579462e+03, 8.99927022e-06, 3.20139261e-04,
                            9.09596835e-04, 3.80055080e-05, 6.82128053e-05, 6.98938631e-06,
                            2.33191693e+01, 3.77100918e+01, 1.12714643e+03, 3.23597671e+05,
                            5.20403629e-04, 2.47112650e-02, 4.34475982e-02, 4.31314711e-03,
                            3.82085668e-03, 3.25636075e-04]

    standard_scaler.scale_ = [3.52095076e+00, 4.29725464e+00, 2.42776193e+01, 3.51604754e+02,
                              1.40517641e-02, 5.27663291e-02, 7.96497253e-02, 3.87687325e-02,
                              2.73901809e-02, 7.05415588e-03, 2.77068942e-01, 5.51163427e-01,
                              2.02007710e+00, 4.54510134e+01, 2.99987837e-03, 1.78924359e-02,
                              3.01595231e-02, 6.16486075e-03, 8.25910439e-03, 2.64374475e-03,
                              4.82899258e+00, 6.14085432e+00, 3.35730016e+01, 5.68856459e+02,
                              2.28123569e-02, 1.57198171e-01, 2.08440875e-01, 6.56745545e-02,
                              6.18130785e-02, 1.80453893e-02]

    X_standard = standard_scaler.transform(X)

    return X_standard, y

# %%
X, y = get_data()
# Out:
# [[1.799e+01 1.038e+01 1.228e+02 ... 2.654e-01 4.601e-01 1.189e-01]
#  [2.057e+01 1.777e+01 1.329e+02 ... 1.860e-01 2.750e-01 8.902e-02]
#  [1.969e+01 2.125e+01 1.300e+02 ... 2.430e-01 3.613e-01 8.758e-02]
#  ...
#  [1.660e+01 2.808e+01 1.083e+02 ... 1.418e-01 2.218e-01 7.820e-02]
#  [2.060e+01 2.933e+01 1.401e+02 ... 2.650e-01 4.087e-01 1.240e-01]
#  [7.760e+00 2.454e+01 4.792e+01 ... 0.000e+00 2.871e-01 7.039e-02]]

# %%
print(X)
# Out:
# [[ 1.09706399 -2.07333501  1.26993369 ...  2.29607613  2.75062225
#    1.93701461]
#  [ 1.82982062 -0.35363241  1.68595471 ...  1.0870843  -0.24388966
#    0.28118999]
#  [ 1.57988813  0.45618695  1.56650313 ...  1.95500035  1.152255
#    0.20139121]
#  ...
#  [ 0.70228426  2.0455738   0.67267578 ...  0.41406869 -1.10454895
#   -0.31840916]
#  [ 1.83834105  2.33645719  1.98252415 ...  2.28998549  1.91908301
#    2.21963528]
#  [-1.80840123  1.22179204 -1.81438851 ... -1.74506282 -0.04813821
#   -0.75120669]]
